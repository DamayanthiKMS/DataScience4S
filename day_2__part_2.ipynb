# %% [markdown]
# <a href="https://colab.research.google.com/github/DamayanthiKMS/DataScience4S/blob/main/day_2__part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy  as np
import matplotlib.pyplot as plt
import pandas as pd
 # read data
 df = pd.read_csv('data.csv')

 #display the first 10 elements of the dataframe
 print(df.head(10))

# X = Hours, t =Scores and convertung them to numpy arrays.
# X desing matrix
X_ori = np.array(df['Hours']).reshape(-1,1) # size N*1
t = np.array(df['Scores']).reshape(-1,1) # size N*1
print(X_ori.shape, t.shape)

# plot data'
plt.scatter(X.ori, t)
plt.title("Data")
plt.xlabel('x (input): Hours')
plt.ylabel('t(targets): Scores')
plt.show()


N = X_ori.shape[0]
D = X_ori.shape[1]
print('No of instances: ',N)
print(' No of features: ',D)

#append 1
X = np.append(X_ori,np.ones(N,1)),axis = 1)
D = D + 1

w = np.zeros_like(t)
print(X.shape.t.shape,w.shape)

lr = 0.01

for i int range(30):
    y = X.dot(w)
    dldw = (X.T).dot(y-t)
    print(dldw.shape)
 exit()

 for i int range(30):
    y = X.dot(w)
    dldw = (X.T).dot(y-t)/N
    w = w - lr * dldw
    loss.append((y-t)**2).mean())
    print(dldw.shape)
 exit()

# plot loss
fig = plt.figure(figsize =(8,6))
plt.plot([i for i in range(neposches)], losses, 'r-1')
plt.xlabel('Number of iterations')
plt.ylabel('loss/Cost')
plt.show()
# Out:
#   File "/tmp/ipython-input-17432045.py", line 5
#     df = pd.read_csv('data.csv')
#     ^
# IndentationError: unexpected indent

# %%
# predictions for the training data
y = np.dot(X,w)
# plotting predictions.
fig = plt.figure(figsize = (8,6))
plt.scatter(X_ori, t)
plt. plot('Hours vs Precentage')
plt.xlabel('X (input): Hours')
plt.ylabel('t (Target): Scores')
plt.show()

# comparing True values to pur predictions.
print(t.shape, y.shape)
compare_df = pd.Dataframe({'Actual': t. reshape(-1),\ 'Predicted' : y.reshape(-1)})
print(Compare_df)

#....batch gradient decent...............#
# Out:
#   File "/tmp/ipython-input-1000924623.py", line 13
#     compare_df = pd.Dataframe({'Actual': t. reshape(-1),\ 'Predicted' : y.reshape(-1)})
#                                                          ^
# SyntaxError: unexpected character after line continuation character

# %%
#....mini batch gradient decent...............#
losses = []
nepoches = 50
bs = 8
for in range(neposches)
  ind  = random. sample(list(range(N)),bs)
  Xbatch = X[ind]
  tbatch = t[ind]

  #prediction
   y = Xbatch.dot(w)
   dldw = (Xbatch.T).dot(y-tbatch)/bs
   w = w-lr*dldw
   losses.append(((y-batch)**2).mean())
