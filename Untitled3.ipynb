# %% [markdown]
# <a href="https://colab.research.google.com/github/DamayanthiKMS/DataScience4S/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
t1 = torch.rand((1,2))
t2 = torch.rand_like(t1)
t3 = torch.tensor([1,2,3]),dtype = torch.int32)
print(t1)
print(t2)
print(t1+t2)
print(t.shape)

tensor([[0.0946]])

# %%
import torch
t1 = torch.rand((1,2))
t2 = torch.rand_like(t1)
t1 = t1.to("cuda:0")
t1 = t1.to("cpu")
print(t1.device)
print(t1.device)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-1095666302.py in <cell line: 0>()
#       2 t1 = torch.rand((1,2))
#       3 t2 = torch.rand_like(t1)
# ----> 4 t1 = t1.to("cuda:0")
#       5 t1 = t1.to("cpu")
#       6 print(t1.device)
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     401             )
#     402         if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403             raise AssertionError("Torch not compiled with CUDA enabled")
#     404         if _cudart is None:
#     405             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
import torch
t1 = torch.tensor([1,2,3])
t1 = torch.tensor([4,5,6])
t1 = t1.to("cuda:0") #
print(t1+t2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4038603318.py in <cell line: 0>()
#       3 t1 = torch.tensor([4,5,6])
#       4 t1 = t1.to("cuda:0") #
# ----> 5 print(t1+t2)
#
# NameError: name 't2' is not defined

# %%
import torch
import numpy as np
d = 300
t1 = torch.rand([d,d])
t2 = torch.rand([d,d])
C  = A.dot(B)
print(c.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3403996270.py in <cell line: 0>()
#       4 t1 = torch.rand([d,d])
#       5 t2 = torch.rand([d,d])
# ----> 6 C  = A.dot(B)
#       7 print(c.shape)
#
# NameError: name 'A' is not defined

# %%
import torch
import numpy as np
import time

d = 3000


#GPU
st = time.time()
A = torch.rand(d,d)
B = torch.rand(d,d)
c = torch.matmul(A,B)
ed = time.time()
print("time for execution on GPU:',ed-st)
# Out:
#   File "/tmp/ipython-input-1422358252.py", line 14
#     print("time for execution on GPU:',ed-st)
#           ^
# SyntaxError: unterminated string literal (detected at line 14)

# %%
import numpy as np
import time

devce = 'cpu'
if torch.cuda.is_available():
  device = 'cuda:0'
t1 = torch.tensor([1,2,3]).to(device)
print(t1)
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %%
import numpy as np
import time

devce = 'cpu'
if torch.cuda.is_available():
  device = 'cuda:0'
t1 = torch.rand(2,3).to(device)
print(t1)
# print only the seond row
print(t1[1,:])
#print only the second column
print(t1[:,1])
print(t1[2:,2:])
# Out:
# tensor([[0.5733, 0.4251, 0.4659],
#         [0.2023, 0.6042, 0.8912]], device='cuda:0')
# tensor([0.2023, 0.6042, 0.8912], device='cuda:0')
# tensor([0.4251, 0.6042], device='cuda:0')
# tensor([], device='cuda:0', size=(0, 1))

# %%
import numpy as np
import time

devce = 'cpu'
if torch.cuda.is_available():
  device = 'cuda:0'
  t1 = torch.rand(5).to(device)
  idx = torch.tensor([3,2,4])
  print(t1)
  print(t1[idx])
# Out:
# tensor([0.2430, 0.5924, 0.7740, 0.4621, 0.1635], device='cuda:0')
# tensor([0.4621, 0.7740, 0.1635], device='cuda:0')

# %%
import numpy as np
import time

devce = 'cpu'
if torch.cuda.is_available():
  device = 'cuda:0'
  t1 = torch.rand(5, requires_grad = True).to(device)
  #loss = torch.pow(x,2)  # loss.sum()
  #loss = x.pow(2).sum()
  y = x.pow(2).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3924008027.py in <cell line: 0>()
#       6   device = 'cuda:0'
#       7   t1 = torch.rand(5, requires_grad = True).to(device)
# ----> 8   loss = torch.pow(x,2)  # loss.sum()
#       9   loss = x.pow(2).sum()
#
# NameError: name 'x' is not defined

# %%
import numpy as np
import time

devce = 'cpu'
if torch.cuda.is_available():
  device = 'cuda:0'

d = 3
x =  torch.tensor(1.).to (device)
w = torch = (y-t).pow(2)
w.retain_grad()
loss.backward()
print(w.data)
print(w.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-762903499.py in <cell line: 0>()
#       8 d = 3
#       9 x =  torch.tensor(1.).to (device)
# ---> 10 w = torch = (y-t).pow(2)
#      11 w.retain_grad()
#      12 loss.backward()
#
# NameError: name 'y' is not defined

# %%
import numpy as np
import time

devce = 'cpu'
if torch.cuda.is_available():
  device = 'cuda:0'
x = torch.tensor(1. ,device = device)
w = torch.tensor(2., device = device, requires_grad = true)
b = torch.tensor(3., device = device , requires_grad = true)
t = torch.tensor(1., device = device)
y = w*x +d
loss = (y-t).pow(2)
loss.backward() #calculate the gradients
print(w.data)
print(w.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-21454556.py in <cell line: 0>()
#       6   device = 'cuda:0'
#       7 x = torch.tensor(1. ,device = device)
# ----> 8 w = torch.tensor(2., device = device, requires_grad = true)
#       9 b = torch.tensor(3., device = device , requires_grad = true)
#      10 t = torch.tensor(1., device = device)
#
# NameError: name 'true' is not defined

# %%
n  = 5
xori = torch.arange(n, device = device)
t = (2*xori)

# %%
import torch
import numpy as np
a = np.arrayy([1,2,3]) ..# python numpy
t = torch.from_numpy(a).cuda # pytorch tensor
b = t.cpu().numpy() # tensor ---> numpy

# %%
import torch
import numpy as np
t = torch.rand(5)
prnt(t.view(-1,1).shape)
print(t.view(1,-1).shape

# %%
print(xori.shape)
X = torch.cat(xori.view(-1,1), torch.ones(n))
