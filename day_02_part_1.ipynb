# %% [markdown]
# <a href="https://colab.research.google.com/github/DamayanthiKMS/DataScience4S/blob/main/day_02_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read datset
df_Stock = pd.read_csv('./AAPL.csv')
df_Stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3732 entries, 0 to 3731
# Data columns (total 64 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              3732 non-null   object
#  1   Open              3732 non-null   float64
#  2   High              3732 non-null   float64
#  3   Low               3732 non-null   float64
#  4   Close(t)          3732 non-null   float64
#  5   Volume            3732 non-null   int64
#  6   SD20              3732 non-null   float64
#  7   Upper_Band        3732 non-null   float64
#  8   Lower_Band        3732 non-null   float64
#  9   S_Close(t-1)      3732 non-null   float64
#  10  S_Close(t-2)      3732 non-null   float64
#  11  S_Close(t-3)      3732 non-null   float64
#  12  S_Close(t-5)      3732 non-null   float64
#  13  S_Open(t-1)       3732 non-null   float64
#  14  MA5               3732 non-null   float64
#  15  MA10              3732 non-null   float64
# ...

# %%
df_Stock = df_Stock.rename(columns={'close(t)': 'Close'})
print(df_Stock.head())
print(df_Stock.tail(5))
# Out:
#          Date  Open  High   Low  Close(t)     Volume      SD20  Upper_Band  \
# 0  2005-10-17  6.66  6.69  6.50      6.60  154208600  0.169237    6.827473
# 1  2005-10-18  6.57  6.66  6.44      6.45  152397000  0.168339    6.819677
# 2  2005-10-19  6.43  6.78  6.32      6.78  252170800  0.180306    6.861112
# 3  2005-10-20  6.72  6.97  6.71      6.93  339440500  0.202674    6.931847
# 4  2005-10-21  7.02  7.03  6.83      6.87  199181500  0.216680    6.974860
#
#    Lower_Band  S_Close(t-1)  ...  QQQ_MA10  QQQ_MA20  QQQ_MA50  SnP_Close  \
# 0    6.150527          6.67  ...    33.692   33.9970   34.2690    1190.10
# 1    6.146323          6.60  ...    33.570   33.9525   34.2466    1178.14
# 2    6.139888          6.45  ...    33.562   33.9600   34.2330    1195.76
# 3    6.121153          6.78  ...    33.567   33.9455   34.2190    1177.80
# 4    6.108140          6.93  ...    33.586   33.9365   34.2034    1179.59
#
# ...

# %%
#plot
df_Stock['Close(t)'].plot(figsize = (10,7))
plt.title("Stock Price",fontsize = 14)
plt. ylabel('Price',fontsize =14)
plt.Xlabel('Date',fontsize = 14)
plt.grid(which = "major", color = 'k',linestyle ='-.',linewidth =0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3177416344.py in <cell line: 0>()
#       3 plt.title("Stock Price",fontsize = 14)
#       4 plt. ylabel('Price',fontsize =14)
# ----> 5 plt.Xlabel('Date',fontsize = 14)
#       6 plt.grid(which = "major", color = 'k',linestyle ='-.',linewidth =0.5)
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Xlabel'

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

def splitTrainTest(df, p=0.8):
    # target variable
    y = df['Close_forecast']

    # features
    X = df.drop(columns=['Close_forecast'])

    n = len(df)
    ntr = int(n * p)

    X_train = X.iloc[:ntr]
    y_train = y.iloc[:ntr]

    X_test = X.iloc[ntr:]
    y_test = y.iloc[ntr:]

    print("X_train:", X_train.shape)
    print("y_train:", y_train.shape)
    print("X_test :", X_test.shape)
    print("y_test :", y_test.shape)

    return X_train, X_test, y_train, y_test

    X_train, X_test, y_train, y_test = splitTrainTest(df_Stock)

lr = LinearRegression()
lr.fit(X_train, y_train)
print('LR Coefficients : \n', lr.coef_)
print('LR Intercept: \n',lr.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1321375560.py in <cell line: 0>()
#      28
#      29 lr = LinearRegression()
# ---> 30 lr.fit(X_train, y_train)
#      31 print('LR Coefficients : \n', lr.coef_)
#      32 print('LR Intercept: \n',lr.intercept_)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn import metrics
# testing
y_train_pred = lr.predict(X_train)
Y_test_pred = lr.predict(X_test)
print("Training R-squared:", round(metrics. r2_score(y_train, Y_train_pred),2))
print("Testing R-squared:", round(metrics.r2_score(y_test,Y_test_pred),2))

df_pred = pd.Dataframe(yte.values,columns = ['Actual'])
df_pred['Predicted'] = Y_test_pred
df_pred[['Actual', 'predicted']].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3754753061.py in <cell line: 0>()
#       1 from sklearn import metrics
#       2 # testing
# ----> 3 y_train_pred = lr.predict(X_train)
#       4 Y_test_pred = lr.predict(X_test)
#       5 print("Training R-squared:", round(metrics. r2_score(y_train, Y_train_pred),2))
#
# NameError: name 'X_train' is not defined
